# %%
import pandas as pd

data = pd.read_csv('dataset.csv')

for col in data.columns:
    print(col)
    print(data[col].value_counts())
    print()
# Out:
# biopsy_preTreat
# biopsy_preTreat
# Y    45560
# Name: count, dtype: int64
#
# pCR_postTrt_days
# pCR_postTrt_days
# 84    45560
# Name: count, dtype: int64
#
# tumor_size_cm_preTrt_preSurgery
# tumor_size_cm_preTrt_preSurgery
# 4.0     43195
# 2.0       887
# 3.0       666
# 5.0       222
# 6.0       221
# 1.0       158
# 7.0        95
# 8.0        53
# 10.0       15
# 9.0        13
# 11.0       10
# 0.0         8
# 12.0        5
# 13.0        4
# 14.0        4
# 17.0        1
# 25.0        1
# 18.0        1
# 15.0        1
# Name: count, dtype: int64
#
# tumor_size_cm_secondAxis_preTrt_preSurgery
# tumor_size_cm_secondAxis_preTrt_preSurgery
# 5.0    43547
# 6.0     1824
# 4.0      147
# 7.0       38
# 3.0        3
# 8.0        1
# Name: count, dtype: int64
#
# tumor_size_cm_postTrt
# tumor_size_cm_postTrt
# 1.0    44895
# 0.0      495
# 2.0      168
# 3.0        1
# 4.0        1
# Name: count, dtype: int64
#
# preTrt_totalLymphNodes
# preTrt_totalLymphNodes
# 12    43023
# 9       362
# 11      351
# 7       223
# 15      212
# 8       203
# 13      184
# 14      183
# 10      180
# 0       132
# 16       99
# 17       89
# 19       72
# 18       67
# 5        60
# 20       31
# 21       21
# 6        20
# 4        15
# 22       10
# 3         4
# 24        3
# 2         3
# 23        3
# 28        2
# 26        2
# 27        1
# 31        1
# 29        1
# 38        1
# 1         1
# 40        1
# Name: count, dtype: int64
#
# preTrt_numPosLymphNodes
# preTrt_numPosLymphNodes
# 2     43271
# 0       654
# 1       628
# 3       541
# 4       189
# 5       157
# 6        46
# 7        38
# 8        15
# 11        6
# 12        4
# 10        3
# 9         2
# 33        1
# 29        1
# 16        1
# 23        1
# 19        1
# 22        1
# Name: count, dtype: int64
#
# postTrt_numPosLymphNodes
# postTrt_numPosLymphNodes
# 4     43219
# 2       698
# 3       391
# 1       293
# 7       233
# 5       149
# 6       127
# 0       122
# 10      110
# 8        71
# 11       51
# 9        48
# 12       29
# 15       15
# 14        1
# 17        1
# 16        1
# 13        1
# Name: count, dtype: int64
#
# preTrt_posDichLymphNodes
# preTrt_posDichLymphNodes
# 0    44529
# 1     1031
# Name: count, dtype: int64
#
# hist_grade
# hist_grade
# 2    44330
# 3     1102
# 1      128
# Name: count, dtype: int64
#
# nuclear_grade_preTrt
# nuclear_grade_preTrt
# 2    43800
# 3     1745
# 1       15
# Name: count, dtype: int64
#
# pCR
# pCR
# N    45186
# Y      374
# Name: count, dtype: int64
#
# near_pCR
# near_pCR
# N    44898
# Y      662
# Name: count, dtype: int64
#
# RFS
# RFS
# 1    45092
# 0      468
# Name: count, dtype: int64
#
# DFS
# DFS
# 1    45147
# 0      413
# Name: count, dtype: int64
#
# OS
# OS
# 1    44310
# 0     1250
# Name: count, dtype: int64
#
# metastasis
# metastasis
# N    45294
# Y      266
# Name: count, dtype: int64
#
# metastasis_months
# metastasis_months
# 16    43156
# 14      756
# 18      460
# 13      459
# 15      226
# 17      196
# 19      149
# 10       86
# 20       25
# 11       11
# 12       10
# 23        9
# 22        5
# 21        4
# 9         2
# 6         1
# 2         1
# 24        1
# 27        1
# 1         1
# 35        1
# Name: count, dtype: int64
#
# died_from_cancer_if_dead
# died_from_cancer_if_dead
# N    43805
# Y     1755
# Name: count, dtype: int64
#
# age
# age
# 54    42917
# 74      247
# 71      151
# 51      123
# 53      121
#       ...
# 85        2
# 24        2
# 92        1
# 87        1
# 25        1
# Name: count, Length: 65, dtype: int64
#
# ER_preTrt
# ER_preTrt
# Y    44710
# N      850
# Name: count, dtype: int64
#
# ER_fmolmg_preTrt
# ER_fmolmg_preTrt
# 112    42841
# 143      233
# 234      137
# 94       114
# 2         97
#        ...
# 165        1
# 370        1
# 310        1
# 179        1
# 24         1
# Name: count, Length: 258, dtype: int64
#
# ESR1_preTrt
# ESR1_preTrt
# N    44846
# Y      714
# Name: count, dtype: int64
#
# ERbb2_preTrt
# ERbb2_preTrt
# N    45394
# Y      166
# Name: count, dtype: int64
#
# Erbeta_preTrt
# Erbeta_preTrt
# Y    45533
# N       27
# Name: count, dtype: int64
#
# ERBB2_CPN_amplified
# ERBB2_CPN_amplified
# N    45424
# Y      136
# Name: count, dtype: int64
#
# PR_preTrt
# PR_preTrt
# Y    44329
# N     1231
# Name: count, dtype: int64
#
# PR_percentage_preTrt
# PR_percentage_preTrt
# 28    42921
# 0       601
# 58      435
# 47      213
# 49      152
#       ...
# 13        2
# 80        2
# 90        2
# 95        2
# 26        2
# Name: count, Length: 72, dtype: int64
#
# PR_fmolmg_preTrt
# PR_fmolmg_preTrt
# 111    42841
# 91       230
# 1        144
# 216      138
# 154      104
#        ...
# 373        1
# 151        1
# 20         1
# 368        1
# 399        1
# Name: count, Length: 239, dtype: int64
#
# HER2_preTrt
# HER2_preTrt
# N    45228
# Y      332
# Name: count, dtype: int64
#
# HER2_fish_cont_score_preTrt
# HER2_fish_cont_score_preTrt
# 2     43270
# 1      1261
# 3       721
# 5       108
# 4       100
# 6        51
# 7        16
# 9        10
# 8         9
# 0         7
# 10        3
# 11        2
# 12        1
# 20        1
# Name: count, dtype: int64
#
# cytokeratin5_pos
# cytokeratin5_pos
# N    45451
# Y      109
# Name: count, dtype: int64
#
# top2atri_preTrt
# top2atri_preTrt
#  0    45490
#  1       38
# -1       32
# Name: count, dtype: int64
#
# topoihc_preTrt
# topoihc_preTrt
# 23    42866
# 8       383
# 14      186
# 17      165
# 18      159
# 13      154
# 12      131
# 33      111
# 28       93
# 19       89
# 30       84
# 21       83
# 15       76
# 20       74
# 26       64
# 25       63
# 31       60
# 10       52
# 34       50
# 32       49
# 5        49
# 27       43
# 16       40
# 37       38
# 39       37
# 35       37
# 22       33
# 7        31
# 40       29
# 29       29
# 24       23
# 6        22
# 36       16
# 38       15
# 44       15
# 11       14
# 41       14
# 9        13
# 42       12
# 52        9
# 72        8
# 54        7
# 53        5
# 50        5
# 2         4
# 48        4
# 80        3
# 0         3
# 90        2
# 70        2
# 68        1
# 82        1
# 63        1
# 47        1
# 1         1
# 76        1
# Name: count, dtype: int64
#
# S_phase
# S_phase
# 11    43301
# 9       466
# 6       356
# 10      324
# 12      263
# 7       147
# 8       143
# 14      128
# 15      119
# 13      108
# 16       78
# 4        39
# 5        31
# 17       14
# 20       12
# 19        7
# 18        5
# 3         5
# 2         4
# 26        2
# 28        2
# 1         2
# 21        2
# 32        1
# 36        1
# Name: count, dtype: int64
#
# radiotherapy
# radiotherapy
# N    45051
# Y      509
# Name: count, dtype: int64
#
# postmenopausal_only
# postmenopausal_only
# 0    45457
# 1      103
# Name: count, dtype: int64
#
# anthracycline
# anthracycline
# N    44307
# Y     1253
# Name: count, dtype: int64
#
# taxane
# taxane
# N    44340
# Y     1220
# Name: count, dtype: int64
#
# anti_estrogen
# anti_estrogen
# N    44644
# Y      916
# Name: count, dtype: int64
#
# aromatase_inhibitor
# aromatase_inhibitor
# N    45456
# Y      104
# Name: count, dtype: int64
#
# anti_HER2
# anti_HER2
# N    45506
# Y       54
# Name: count, dtype: int64
#
# tamoxifen
# tamoxifen
# 0    44748
# 1      812
# Name: count, dtype: int64
#
# doxorubicin
# doxorubicin
# N    44751
# Y      809
# Name: count, dtype: int64
#
# epirubicin
# epirubicin
# N    45116
# Y      444
# Name: count, dtype: int64
#
# docetaxel
# docetaxel
# N    45227
# Y      333
# Name: count, dtype: int64
#
# capecitabine
# capecitabine
# N    45345
# Y      215
# Name: count, dtype: int64
#
# fluorouracil
# fluorouracil
# N    44760
# Y      800
# Name: count, dtype: int64
#
# paclitaxel
# paclitaxel
# N    44820
# Y      740
# Name: count, dtype: int64
#
# cyclophosphamide
# cyclophosphamide
# N    44499
# Y     1061
# Name: count, dtype: int64
#
# anastrozole
# anastrozole
# N    45548
# Y       12
# Name: count, dtype: int64
#
# fulvestrant
# fulvestrant
# N    45549
# Y       11
# Name: count, dtype: int64
#
# gefitinib
# gefitinib
# N    45549
# Y       11
# Name: count, dtype: int64
#
# trastuzumab
# trastuzumab
# N    45506
# Y       54
# Name: count, dtype: int64
#
# letrozole
# letrozole
# N    45468
# Y       92
# Name: count, dtype: int64
#
# chemotherapy
# chemotherapy
# N    45529
# Y       31
# Name: count, dtype: int64
#
# hormone_therapy
# hormone_therapy
# N    45551
# Y        9
# Name: count, dtype: int64
#
# methotrexate
# methotrexate
# N    45556
# Y        4
# Name: count, dtype: int64
#
# cetuximab
# cetuximab
# N    45546
# Y       14
# Name: count, dtype: int64
#
# carboplatin
# carboplatin
# N    45546
# Y       14
# Name: count, dtype: int64
#
# other_treatment
# other_treatment
# N    45414
# Y      146
# Name: count, dtype: int64
#
# tumor_size_cm_postTrt_1
# tumor_size_cm_postTrt_1
# 1.0    30951
# 2.0     7559
# 0.0     7050
# Name: count, dtype: int64
#
# postTrt_numPosLymphNodes_1
# postTrt_numPosLymphNodes_1
# 4.0     14250
# 3.0      5723
# 0.0      4820
# 5.0      4753
# 2.0      4035
# 1.0      3987
# 6.0      2381
# 8.0      1119
# 7.0      1095
# 9.0       864
# 12.0      511
# 14.0      492
# 10.0      462
# 11.0      446
# 13.0      391
# 15.0      231
# Name: count, dtype: int64
#
# metastasis_1
# metastasis_1
# N    38951
# Y     6609
# Name: count, dtype: int64
#
# metastasis_months_1
# metastasis_months_1
# 16.0    13654
# 17.0     5654
# 14.0     5630
# 15.0     5274
# 13.0     4434
# 18.0     3996
# 12.0     2132
# 19.0     1413
# 20.0      622
# 23.0      618
# 21.0      596
# 22.0      543
# 10.0      359
# 11.0      295
# 25.0      186
# 24.0      154
# Name: count, dtype: int64
#
# tumor_size_cm_postTrt_2
# tumor_size_cm_postTrt_2
# 1.0    32347
# 2.0     6851
# 0.0     6362
# Name: count, dtype: int64
#
# postTrt_numPosLymphNodes_2
# postTrt_numPosLymphNodes_2
# 4.0     15159
# 2.0      4630
# 0.0      4562
# 3.0      4558
# 5.0      4420
# 1.0      4361
# 7.0      1918
# 6.0      1786
# 8.0      1015
# 10.0      698
# 9.0       685
# 11.0      453
# 12.0      391
# 15.0      334
# 14.0      303
# 13.0      287
# Name: count, dtype: int64
#
# metastasis_2
# metastasis_2
# N    39455
# Y     6105
# Name: count, dtype: int64
#
# metastasis_months_2
# metastasis_months_2
# 16.0    14438
# 15.0     5377
# 14.0     4976
# 17.0     4561
# 13.0     4117
# 18.0     3638
# 12.0     2917
# 11.0     1559
# 22.0      847
# 21.0      746
# 20.0      714
# 19.0      711
# 10.0      412
# 23.0      213
# 25.0      174
# 24.0      160
# Name: count, dtype: int64
#
# clinical_AJCC_stage
# clinical_AJCC_stage
# IIB     45086
# IIA       136
# II        108
# IIIA      102
# IIIB       80
# IIIC       20
# IV         16
# I           9
# III         3
# Name: count, dtype: int64
#
# treatment_admin
# treatment_admin
# oral           44899
# NOS              389
# intarvenous      272
# Name: count, dtype: int64
#
# Race
# Race
# White       45472
# Hispanic       40
# Black          28
# Asian          18
# Mixed           2
# Name: count, dtype: int64
#
# preTrt_lymph_node_status
# preTrt_lymph_node_status
# N0          44578
# N1            442
# positive      363
# N2             91
# N3             79
# ND              7
# Name: count, dtype: int64
#
# postTrt_lymph_node_status
# postTrt_lymph_node_status
# N0          45516
# positive       35
# N1a             4
# N2a             2
# N3              1
# N2              1
# N1              1
# Name: count, dtype: int64
#
# tumor_stage_postTrt
# tumor_stage_postTrt
# T1c      45536
# T0           6
# T1b          5
# T1a          5
# T2           3
# Tis          3
# T1           1
# T1mic        1
# Name: count, dtype: int64
#
# tumor_stage_preTrt
# tumor_stage_preTrt
# T2    44865
# T1      295
# T3      253
# T4      141
# T0        6
# Name: count, dtype: int64
#
# pam50
# pam50
# Basal        45011
# Luminal A      237
# Luminal B      142
# Her2            83
# Normal          67
# Claudin         20
# Name: count, dtype: int64
#
# pCR_spectrum
# pCR_spectrum
# PR     45510
# CR        22
# NCR       10
# PD         8
# SD         7
# EPD        2
# NE         1
# Name: count, dtype: int64
#
# RCB
# RCB
# II     45143
# 0/I      101
# 2         95
# III       89
# 3         66
# 0         47
# 1         19
# Name: count, dtype: int64
#
# menopausal_status
# menopausal_status
# post    45421
# pre       139
# Name: count, dtype: int64
#
# HER2_IHC_score_preTrt
# HER2_IHC_score_preTrt
# NEG    45302
# 0         75
# 3         70
# 1         55
# 2         36
# ND        22
# Name: count, dtype: int64
#
# ploidy
# ploidy
# aneuploid     45546
# diploid          10
# multiploid        4
# Name: count, dtype: int64
#
# estrogen_receptor
# estrogen_receptor
# NOS                    45456
# block_and_stop            93
# block_and_eliminate       11
# Name: count, dtype: int64
#
# surgery
# surgery
# preserving    45518
# mastectomy       42
# Name: count, dtype: int64
#
# therapy
# therapy
# neo            44128
# adj             1136
# mixed            186
# unspecified      110
# Name: count, dtype: int64

# %%
import pandas as pd

data = pd.read_csv('synthetic_dataset.csv')

for col in data.columns:
    print(col)
    print(data[col].value_counts())
    print()
# Out:
# age
# age
# 58    88
# 50    87
# 53    84
# 54    82
# 55    80
#       ..
# 84     1
# 27     1
# 23     1
# 89     1
# 91     1
# Name: count, Length: 66, dtype: int64
#
# menopausal_status
# menopausal_status
# Post    1267
# Pre      733
# Name: count, dtype: int64
#
# stage
# stage
# 1    792
# 2    576
# 3    424
# 4    208
# Name: count, dtype: int64
#
# tumor_size
# tumor_size
# 0.100000    7
# 8.139815    1
# 5.383024    1
# 0.539699    1
# 3.414040    1
#            ..
# 5.142078    1
# 1.529724    1
# 1.082207    1
# 2.231309    1
# 1.055409    1
# Name: count, Length: 1994, dtype: int64
#
# lymph_nodes
# lymph_nodes
# 0     684
# 1     524
# 7     158
# 2     156
# 6     147
# 5     137
# 8      69
# 4      59
# 3      44
# 9      19
# 10      3
# Name: count, dtype: int64
#
# histology
# histology
# Ductal     1615
# Lobular     171
# Other       112
# Mixed       102
# Name: count, dtype: int64
#
# grade
# grade
# 2    851
# 3    677
# 1    472
# Name: count, dtype: int64
#
# er_status
# er_status
# Positive    1603
# Negative     397
# Name: count, dtype: int64
#
# pr_status
# pr_status
# Positive    1500
# Negative     500
# Name: count, dtype: int64
#
# her2_status
# her2_status
# Negative    1584
# Positive     416
# Name: count, dtype: int64
#
# ki67_expression
# ki67_expression
# 37.666384    1
# 17.206000    1
# 19.264967    1
# 12.769088    1
# 9.876459     1
#             ..
# 15.881790    1
# 19.231052    1
# 25.196160    1
# 21.132369    1
# 51.883229    1
# Name: count, Length: 2000, dtype: int64
#
# oncotype_score
# oncotype_score
# 0.000000     24
# 11.326334     1
# 8.235620      1
# 5.608637      1
# 4.976548      1
#              ..
# 24.523444     1
# 16.105399     1
# 10.738804     1
# 32.130329     1
# 26.998775     1
# Name: count, Length: 1977, dtype: int64
#
# surgery
# surgery
# Mastectomy    1327
# Lumpectomy     673
# Name: count, dtype: int64
#
# tumor_size_post_surgery
# tumor_size_post_surgery
# 0.000000    1327
# 0.139712       1
# 0.125437       1
# 0.117286       1
# 0.021558       1
#             ...
# 0.083608       1
# 0.078193       1
# 0.092905       1
# 0.037788       1
# 0.154242       1
# Name: count, Length: 674, dtype: int64
#
# lymph_nodes_post_surgery
# lymph_nodes_post_surgery
# 0    1979
# 1      14
# 2       6
# 3       1
# Name: count, dtype: int64
#
# chemotherapy
# chemotherapy
# Yes    1654
# No      346
# Name: count, dtype: int64
#
# tumor_size_post_chemo
# tumor_size_post_chemo
# 0.000000    1327
# 0.053404       1
# 0.026268       1
# 0.043626       1
# 0.005122       1
#             ...
# 0.017310       1
# 0.078193       1
# 0.092905       1
# 0.037788       1
# 0.022128       1
# Name: count, Length: 674, dtype: int64
#
# lymph_nodes_post_chemo
# lymph_nodes_post_chemo
# 0    1993
# 1       5
# 2       2
# Name: count, dtype: int64
#
# recurrence_post_chemo
# recurrence_post_chemo
# 0    1841
# 1     159
# Name: count, dtype: int64
#
# hormone_therapy
# hormone_therapy
# Yes    1653
# No      347
# Name: count, dtype: int64
#
# tumor_size_post_hormone
# tumor_size_post_hormone
# 0.000000    1327
# 0.048834       1
# 0.021165       1
# 0.038049       1
# 0.004013       1
#             ...
# 0.016037       1
# 0.063455       1
# 0.075434       1
# 0.027012       1
# 0.017125       1
# Name: count, Length: 674, dtype: int64
#
# lymph_nodes_post_hormone
# lymph_nodes_post_hormone
# 0    1993
# 1       5
# 2       2
# Name: count, dtype: int64
#
# recurrence_post_hormone
# recurrence_post_hormone
# 0    1915
# 1      85
# Name: count, dtype: int64
#
# radiotherapy
# radiotherapy
# Yes    1739
# No      261
# Name: count, dtype: int64
#
# tumor_size_post_radio
# tumor_size_post_radio
# 0.000000    1327
# 0.040721       1
# 0.018467       1
# 0.033091       1
# 0.003514       1
#             ...
# 0.014753       1
# 0.053183       1
# 0.067700       1
# 0.024179       1
# 0.015162       1
# Name: count, Length: 674, dtype: int64
#
# lymph_nodes_post_radio
# lymph_nodes_post_radio
# 0    1994
# 1       5
# 2       1
# Name: count, dtype: int64
#
# recurrence_post_radio
# recurrence_post_radio
# 0    1966
# 1      34
# Name: count, dtype: int64
#
# OS
# OS
# 1    1760
# 0     240
# Name: count, dtype: int64
#
# DFS
# DFS
# 1    1661
# 0     339
# Name: count, dtype: int64
#
# RFS
# RFS
# 1    1602
# 0     398
# Name: count, dtype: int64

# %%
data['surgery']. value_counts()
# Out:
# surgery
# Mastectomy    1327
# Lumpectomy     673
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 94 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   surgery                                     2000 non-null   object
#  1   chemotherapy                                2000 non-null   object
#  2   hormone_therapy                             2000 non-null   object
#  3   radiotherapy                                2000 non-null   object
#  4   PR_percentage_preTrt                        2000 non-null   float64
#  5   metastasis_months_2                         2000 non-null   int64
#  6   preTrt_numPosLymphNodes                     2000 non-null   int64
#  7   PR_fmolmg_preTrt                            2000 non-null   int64
#  8   preTrt_totalLymphNodes                      2000 non-null   int64
#  9   ER_fmolmg_preTrt                            2000 non-null   int64
#  10  pCR_postTrt_days                            2000 non-null   int64
#  11  postTrt_numPosLymphNodes                    2000 non-null   int64
#  12  topoihc_preTrt                              2000 non-null   int64
#  13  metastasis_months                           2000 non-null   int64
#  14  age                                         2000 non-null   int64
#  15  tumor_size                                  2000 non-null   float64
#  16  lymph_nodes                                 2000 non-null   int64
#  17  hormone_receptor_status                     2000 non-null   object
#  18  her2_status                                 2000 non-null   object
#  19  grade                                       2000 non-null   int64
#  20  stage                                       2000 non-null   int64
#  21  histology                                   2000 non-null   object
#  22  Ki67_expression                             2000 non-null   float64
#  23  oncotype_score                              2000 non-null   float64
#  24  OS                                          2000 non-null   int64
#  25  DFS                                         2000 non-null   int64
#  26  RFS                                         2000 non-null   int64
#  27  biopsy_preTreat                             2000 non-null   int64
#  28  tumor_size_cm_preTrt_preSurgery             2000 non-null   int64
#  29  tumor_size_cm_secondAxis_preTrt_preSurgery  2000 non-null   int64
#  30  tumor_size_cm_postTrt                       2000 non-null   int64
#  31  preTrt_posDichLymphNodes                    2000 non-null   int64
#  32  hist_grade                                  2000 non-null   int64
#  33  nuclear_grade_preTrt                        2000 non-null   int64
#  34  pCR                                         2000 non-null   int64
#  35  near_pCR                                    2000 non-null   int64
#  36  metastasis                                  2000 non-null   int64
#  37  died_from_cancer_if_dead                    2000 non-null   int64
#  38  ER_preTrt                                   2000 non-null   int64
#  39  ESR1_preTrt                                 2000 non-null   int64
#  40  ERbb2_preTrt                                2000 non-null   int64
#  41  Erbeta_preTrt                               2000 non-null   int64
#  42  ERBB2_CPN_amplified                         2000 non-null   int64
#  43  PR_preTrt                                   2000 non-null   int64
#  44  HER2_preTrt                                 2000 non-null   int64
#  45  HER2_fish_cont_score_preTrt                 2000 non-null   int64
#  46  cytokeratin5_pos                            2000 non-null   int64
#  47  top2atri_preTrt                             2000 non-null   int64
#  48  S_phase                                     2000 non-null   int64
#  49  postmenopausal_only                         2000 non-null   int64
#  50  anthracycline                               2000 non-null   int64
#  51  taxane                                      2000 non-null   int64
#  52  anti_estrogen                               2000 non-null   int64
#  53  aromatase_inhibitor                         2000 non-null   int64
#  54  anti_HER2                                   2000 non-null   int64
#  55  tamoxifen                                   2000 non-null   int64
#  56  doxorubicin                                 2000 non-null   int64
#  57  epirubicin                                  2000 non-null   int64
#  58  docetaxel                                   2000 non-null   int64
#  59  capecitabine                                2000 non-null   int64
#  60  fluorouracil                                2000 non-null   int64
#  61  paclitaxel                                  2000 non-null   int64
#  62  cyclophosphamide                            2000 non-null   int64
#  63  anastrozole                                 2000 non-null   int64
#  64  fulvestrant                                 2000 non-null   int64
#  65  gefitinib                                   2000 non-null   int64
#  66  trastuzumab                                 2000 non-null   int64
#  67  letrozole                                   2000 non-null   int64
#  68  methotrexate                                2000 non-null   int64
#  69  cetuximab                                   2000 non-null   int64
#  70  carboplatin                                 2000 non-null   int64
#  71  other_treatment                             2000 non-null   int64
#  72  tumor_size_cm_postTrt_1                     2000 non-null   int64
#  73  postTrt_numPosLymphNodes_1                  2000 non-null   int64
#  74  metastasis_1                                2000 non-null   int64
#  75  metastasis_months_1                         2000 non-null   int64
#  76  tumor_size_cm_postTrt_2                     2000 non-null   int64
#  77  postTrt_numPosLymphNodes_2                  2000 non-null   int64
#  78  metastasis_2                                2000 non-null   int64
#  79  clinical_AJCC_stage                         2000 non-null   int64
#  80  treatment_admin                             2000 non-null   int64
#  81  Race                                        2000 non-null   int64
#  82  preTrt_lymph_node_status                    2000 non-null   int64
#  83  postTrt_lymph_node_status                   2000 non-null   int64
#  84  tumor_stage_postTrt                         2000 non-null   int64
#  85  tumor_stage_preTrt                          2000 non-null   int64
#  86  pam50                                       2000 non-null   int64
#  87  pCR_spectrum                                2000 non-null   int64
#  88  RCB                                         2000 non-null   int64
#  89  menopausal_status                           2000 non-null   int64
#  90  HER2_IHC_score_preTrt                       2000 non-null   int64
#  91  ploidy                                      2000 non-null   int64
#  92  estrogen_receptor                           2000 non-null   int64
#  93  therapy                                     2000 non-null   int64
# dtypes: float64(4), int64(83), object(7)
# memory usage: 1.4+ MB

# %%
data['pCR_postTrt_days'].value_counts()
# Out:
# pCR_postTrt_days
# 0.849608    1
# 0.003121    1
# 0.846096    1
# 0.042809    1
# 0.674665    1
#            ..
# 0.267450    1
# 0.780248    1
# 0.949917    1
# 0.141960    1
# 0.608378    1
# Name: count, Length: 1000, dtype: int64

# %%
Treatment Simulator Evaluation Results:
Outcome: OS
Mean Accuracy: 0.8780
95% Confidence Interval: [0.8580, 0.8980]

DQL Model Evaluation Results:
Decision: surgery
Accuracy: 0.0030
Precision: 0.0030
Recall: 0.0030
F1-score: 0.0030
Decision: chemotherapy
Accuracy: 0.4030
Precision: 0.4030
Recall: 0.4030
F1-score: 0.4030
Decision: hormone_therapy
Accuracy: 0.0000
Precision: 0.0000
Recall: 0.0000
F1-score: 0.0000
Decision: radiotherapy
Accuracy: 0.0070
Precision: 0.0070
Recall: 0.0070
F1-score: 0.0070

300 sample without oversampling

with oversampling:

Evaluating Treatment Simulator model for OS
Outcome: OS
Mean Accuracy: 0.8778
95% Confidence Interval: [0.8570, 0.8990]
Treatment Simulator evaluation completed for OS.
Evaluating DQL model for surgery
Evaluation metrics for surgery:
Accuracy: 0.0000
Precision: 0.0000
Recall: 0.0000
F1-score: 0.0000
Evaluating DQL model for chemotherapy
Evaluation metrics for chemotherapy:
Accuracy: 0.0000
Precision: 0.0000
Recall: 0.0000
F1-score: 0.0000
Evaluating DQL model for hormone_therapy
Evaluation metrics for hormone_therapy:
Accuracy: 0.0030
Precision: 0.0030
Recall: 0.0030
F1-score: 0.0030
Evaluating DQL model for radiotherapy
Evaluation metrics for radiotherapy:
Accuracy: 0.0070
Precision: 0.0070
Recall: 0.0070
F1-score: 0.0070
DQL model evaluation completed.
# Out:
#   Cell In[3], line 1
#     Treatment Simulator Evaluation Results:
#               ^
# SyntaxError: invalid syntax
