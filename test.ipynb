# %%
import pandas as pd

data = pd.read_csv('synthetic_dataset.csv')

for col in data.columns:
    print(col)
    print(data[col].value_counts())
    print()
# Out:
# age
# age
# 56    84
# 54    82
# 55    81
# 51    79
# 50    79
#       ..
# 84     1
# 83     1
# 26     1
# 79     1
# 23     1
# Name: count, Length: 61, dtype: int64
#
# menopausal_status
# menopausal_status
# Post    1315
# Pre      685
# Name: count, dtype: int64
#
# stage
# stage
# 1    821
# 2    621
# 3    356
# 4    202
# Name: count, dtype: int64
#
# tumor_size
# tumor_size
# 0.100000    4
# 2.136137    1
# 3.817155    1
# 2.039693    1
# 1.317336    1
#            ..
# 1.476558    1
# 2.253239    1
# 2.189889    1
# 1.275474    1
# 1.929302    1
# Name: count, Length: 1997, dtype: int64
#
# lymph_nodes
# lymph_nodes
# 0     733
# 1     549
# 2     158
# 6     130
# 5     123
# 7     115
# 4      71
# 8      56
# 3      32
# 9      28
# 10      5
# Name: count, dtype: int64
#
# histology
# histology
# Ductal     1586
# Lobular     207
# Mixed       118
# Other        89
# Name: count, dtype: int64
#
# grade
# grade
# 2    894
# 3    608
# 1    498
# Name: count, dtype: int64
#
# er_status
# er_status
# Positive    1585
# Negative     415
# Name: count, dtype: int64
#
# pr_status
# pr_status
# Positive    1462
# Negative     538
# Name: count, dtype: int64
#
# her2_status
# her2_status
# Negative    1614
# Positive     386
# Name: count, dtype: int64
#
# ki67_expression
# ki67_expression
# 9.035153     1
# 16.447741    1
# 4.948288     1
# 19.778089    1
# 12.283232    1
#             ..
# 15.406338    1
# 24.613463    1
# 13.228740    1
# 24.092531    1
# 37.274364    1
# Name: count, Length: 2000, dtype: int64
#
# oncotype_score
# oncotype_score
# 0.000000     35
# 5.129149      1
# 20.350945     1
# 3.479790      1
# 6.900276      1
#              ..
# 6.734730      1
# 13.517900     1
# 5.560692      1
# 9.692128      1
# 23.588371     1
# Name: count, Length: 1966, dtype: int64
#
# surgery
# surgery
# Mastectomy    1624
# Lumpectomy     376
# Name: count, dtype: int64
#
# tumor_size_post_surgery
# tumor_size_post_surgery
# 0.000000    1624
# 0.049436       1
# 0.066727       1
# 0.124678       1
# 0.154039       1
#             ...
# 0.135276       1
# 0.243668       1
# 0.049289       1
# 0.062761       1
# 0.104171       1
# Name: count, Length: 377, dtype: int64
#
# lymph_nodes_post_surgery
# lymph_nodes_post_surgery
# 0    1982
# 1      18
# Name: count, dtype: int64
#
# chemotherapy
# chemotherapy
# Yes    1664
# No      336
# Name: count, dtype: int64
#
# tumor_size_post_chemo
# tumor_size_post_chemo
# 0.000000    1624
# 0.015165       1
# 0.028042       1
# 0.044930       1
# 0.046945       1
#             ...
# 0.135276       1
# 0.122404       1
# 0.049289       1
# 0.062761       1
# 0.039989       1
# Name: count, Length: 377, dtype: int64
#
# lymph_nodes_post_chemo
# lymph_nodes_post_chemo
# 0    1987
# 1      13
# Name: count, dtype: int64
#
# recurrence_post_chemo
# recurrence_post_chemo
# 0    1860
# 1     140
# Name: count, dtype: int64
#
# hormone_therapy
# hormone_therapy
# Yes    1627
# No      373
# Name: count, dtype: int64
#
# tumor_size_post_hormone
# tumor_size_post_hormone
# 0.000000    1624
# 0.010970       1
# 0.021832       1
# 0.040297       1
# 0.042717       1
#             ...
# 0.104963       1
# 0.095685       1
# 0.043227       1
# 0.057115       1
# 0.036504       1
# Name: count, Length: 377, dtype: int64
#
# lymph_nodes_post_hormone
# lymph_nodes_post_hormone
# 0    1987
# 1      13
# Name: count, dtype: int64
#
# recurrence_post_hormone
# recurrence_post_hormone
# 0    1926
# 1      74
# Name: count, dtype: int64
#
# radiotherapy
# radiotherapy
# Yes    1899
# No      101
# Name: count, dtype: int64
#
# tumor_size_post_radio
# tumor_size_post_radio
# 0.000000    1624
# 0.009685       1
# 0.017884       1
# 0.036476       1
# 0.032316       1
#             ...
# 0.098304       1
# 0.081735       1
# 0.041591       1
# 0.053433       1
# 0.034422       1
# Name: count, Length: 377, dtype: int64
#
# lymph_nodes_post_radio
# lymph_nodes_post_radio
# 0    1988
# 1      12
# Name: count, dtype: int64
#
# recurrence_post_radio
# recurrence_post_radio
# 0    1975
# 1      25
# Name: count, dtype: int64
#
# OS
# OS
# 1    1809
# 0     191
# Name: count, dtype: int64
#
# DFS
# DFS
# 1    1712
# 0     288
# Name: count, dtype: int64
#
# RFS
# RFS
# 1    1635
# 0     365
# Name: count, dtype: int64

# %%
data['surgery']. value_counts()
# Out:
# surgery
# Mastectomy    1327
# Lumpectomy     673
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       2000 non-null   int64
#  1   menopausal_status         2000 non-null   object
#  2   stage                     2000 non-null   int64
#  3   tumor_size                2000 non-null   float64
#  4   lymph_nodes               2000 non-null   int64
#  5   histology                 2000 non-null   object
#  6   grade                     2000 non-null   int64
#  7   er_status                 2000 non-null   object
#  8   pr_status                 2000 non-null   object
#  9   her2_status               2000 non-null   object
#  10  ki67_expression           2000 non-null   float64
#  11  oncotype_score            2000 non-null   float64
#  12  surgery                   2000 non-null   object
#  13  tumor_size_post_surgery   2000 non-null   float64
#  14  lymph_nodes_post_surgery  2000 non-null   int64
#  15  chemotherapy              2000 non-null   object
#  16  tumor_size_post_chemo     2000 non-null   float64
#  17  lymph_nodes_post_chemo    2000 non-null   int64
#  18  recurrence_post_chemo     2000 non-null   int64
#  19  hormone_therapy           2000 non-null   object
#  20  tumor_size_post_hormone   2000 non-null   float64
#  21  lymph_nodes_post_hormone  2000 non-null   int64
#  22  recurrence_post_hormone   2000 non-null   int64
#  23  radiotherapy              2000 non-null   object
#  24  tumor_size_post_radio     2000 non-null   float64
#  25  lymph_nodes_post_radio    2000 non-null   int64
#  26  recurrence_post_radio     2000 non-null   int64
#  27  OS                        2000 non-null   int64
#  28  DFS                       2000 non-null   int64
#  29  RFS                       2000 non-null   int64
# dtypes: float64(7), int64(14), object(9)
# memory usage: 468.9+ KB

# %%
for col in data.columns:
    print(col)
# Out:
# age
# menopausal_status
# stage
# tumor_size
# lymph_nodes
# histology
# grade
# er_status
# pr_status
# her2_status
# ki67_expression
# oncotype_score
# surgery
# tumor_size_post_surgery
# lymph_nodes_post_surgery
# chemotherapy
# tumor_size_post_chemo
# lymph_nodes_post_chemo
# recurrence_post_chemo
# hormone_therapy
# tumor_size_post_hormone
# lymph_nodes_post_hormone
# recurrence_post_hormone
# radiotherapy
# tumor_size_post_radio
# lymph_nodes_post_radio
# recurrence_post_radio
# OS
# DFS
# RFS
